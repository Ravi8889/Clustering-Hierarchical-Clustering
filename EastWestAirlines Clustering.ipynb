# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_excel(r"D:\Excel R\Data Science Assignments\Hierarical Clustering\Airlines.xlsx",sheet_name="data")

# %%
data
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 0               1                  0                0               7000
# 1               2                  0                0               6968
# 2               4                  0                0               7034
# 3               1                  0                0               6952
# 4              26               2077                4               6935
# ...           ...                ...              ...                ...
# 3994            4                200                1               1403
# 3995            5                  0                0               1395
# 3996            8                  0                0               1402
# 3997            1                500                1               1401
# 3998            0                  0                0               1398
#
#       Award?
# 0          0
# 1          0
# 2          0
# 3          0
# 4          1
# ...      ...
# 3994       1
# 3995       1
# 3996       1
# 3997       0
# 3998       0
#
# [3999 rows x 12 columns]

# %%
data.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
data.shape
# Out:
# (3999, 12)

# %%
data.dtypes
# Out:
# ID#                  int64
# Balance              int64
# Qual_miles           int64
# cc1_miles            int64
# cc2_miles            int64
# cc3_miles            int64
# Bonus_miles          int64
# Bonus_trans          int64
# Flight_miles_12mo    int64
# Flight_trans_12      int64
# Days_since_enroll    int64
# Award?               int64
# dtype: object

# %%
data.describe()
# Out:
#                ID#       Balance    Qual_miles    cc1_miles    cc2_miles  \
# count  3999.000000  3.999000e+03   3999.000000  3999.000000  3999.000000
# mean   2014.819455  7.360133e+04    144.114529     2.059515     1.014504
# std    1160.764358  1.007757e+05    773.663804     1.376919     0.147650
# min       1.000000  0.000000e+00      0.000000     1.000000     1.000000
# 25%    1010.500000  1.852750e+04      0.000000     1.000000     1.000000
# 50%    2016.000000  4.309700e+04      0.000000     1.000000     1.000000
# 75%    3020.500000  9.240400e+04      0.000000     3.000000     1.000000
# max    4021.000000  1.704838e+06  11148.000000     5.000000     3.000000
#
#          cc3_miles    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# count  3999.000000    3999.000000   3999.00000        3999.000000
# mean      1.012253   17144.846212     11.60190         460.055764
# std       0.195241   24150.967826      9.60381        1400.209171
# min       1.000000       0.000000      0.00000           0.000000
# 25%       1.000000    1250.000000      3.00000           0.000000
# 50%       1.000000    7171.000000     12.00000           0.000000
# 75%       1.000000   23800.500000     17.00000         311.000000
# max       5.000000  263685.000000     86.00000       30817.000000
#
#        Flight_trans_12  Days_since_enroll       Award?
# count      3999.000000         3999.00000  3999.000000
# mean          1.373593         4118.55939     0.370343
# std           3.793172         2065.13454     0.482957
# min           0.000000            2.00000     0.000000
# 25%           0.000000         2330.00000     0.000000
# 50%           0.000000         4096.00000     0.000000
# 75%           1.000000         5790.50000     1.000000
# max          53.000000         8296.00000     1.000000

# %%
data.cc1_miles.unique()
# Out:
# array([1, 4, 3, 2, 5], dtype=int64)

# %%
data.cc2_miles.unique()
# Out:
# array([1, 2, 3], dtype=int64)

# %%
data.cc3_miles.unique()
# Out:
# array([1, 3, 2, 4, 5], dtype=int64)

# %%
data.columns.shape
# Out:
# (12,)

# %%
data.mean()#average values of data
# Out:
# ID#                   2014.819455
# Balance              73601.327582
# Qual_miles             144.114529
# cc1_miles                2.059515
# cc2_miles                1.014504
# cc3_miles                1.012253
# Bonus_miles          17144.846212
# Bonus_trans             11.601900
# Flight_miles_12mo      460.055764
# Flight_trans_12          1.373593
# Days_since_enroll     4118.559390
# Award?                   0.370343
# dtype: float64

# %%
data.count()## Every column has count of Records has 3999
# Out:
# ID#                  3999
# Balance              3999
# Qual_miles           3999
# cc1_miles            3999
# cc2_miles            3999
# cc3_miles            3999
# Bonus_miles          3999
# Bonus_trans          3999
# Flight_miles_12mo    3999
# Flight_trans_12      3999
# Days_since_enroll    3999
# Award?               3999
# dtype: int64

# %%
data.min()## thesee are the minimum values of the data
# Out:
# ID#                  1
# Balance              0
# Qual_miles           0
# cc1_miles            1
# cc2_miles            1
# cc3_miles            1
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    2
# Award?               0
# dtype: int64

# %%
data.max()# Maximum number of the data
# Out:
# ID#                     4021
# Balance              1704838
# Qual_miles             11148
# cc1_miles                  5
# cc2_miles                  3
# cc3_miles                  5
# Bonus_miles           263685
# Bonus_trans               86
# Flight_miles_12mo      30817
# Flight_trans_12           53
# Days_since_enroll       8296
# Award?                     1
# dtype: int64

# %%
data.var()## Variance of the data
# Out:
# ID#                  1.347374e+06
# Balance              1.015573e+10
# Qual_miles           5.985557e+05
# cc1_miles            1.895907e+00
# cc2_miles            2.180060e-02
# cc3_miles            3.811896e-02
# Bonus_miles          5.832692e+08
# Bonus_trans          9.223317e+01
# Flight_miles_12mo    1.960586e+06
# Flight_trans_12      1.438816e+01
# Days_since_enroll    4.264781e+06
# Award?               2.332473e-01
# dtype: float64

# %%
data.std()# Standard Diveation
# Out:
# ID#                    1160.764358
# Balance              100775.664958
# Qual_miles              773.663804
# cc1_miles                 1.376919
# cc2_miles                 0.147650
# cc3_miles                 0.195241
# Bonus_miles           24150.967826
# Bonus_trans               9.603810
# Flight_miles_12mo      1400.209171
# Flight_trans_12           3.793172
# Days_since_enroll      2065.134540
# Award?                    0.482957
# dtype: float64

# %%
data.kurt()#Kurtosis  of the data
# Out:
# ID#                   -1.199648
# Balance               44.157932
# Qual_miles            67.689351
# cc1_miles             -0.748508
# cc2_miles            133.786489
# cc3_miles            308.654728
# Bonus_miles           13.630489
# Bonus_trans            2.745737
# Flight_miles_12mo     94.761019
# Flight_trans_12       42.978152
# Days_since_enroll     -0.967505
# Award?                -1.712272
# dtype: float64

# %%
data['Award?'].value_counts()## Wheather  the Passanger get Free ticket or Not 0 & 1 0 has higher values
# Out:
# 0    2518
# 1    1481
# Name: Award?, dtype: int64

# %% [markdown]
# Dealing with Missing values

# %%
data.isnull().sum()
# Out:
# ID#                  0
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award?               0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %% [markdown]
# By Observing the above results there are no missing values in the data set

# %%
sns.factorplot("Award?",data=data,kind='count',size=5,aspect=.5)
plt.show()
# Out:
# C:\Users\RaviKiran\anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\RaviKiran\anaconda3\lib\site-packages\seaborn\categorical.py:3710: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\RaviKiran\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.factorplot("Bonus_miles",data=data,kind='count',size=5,aspect=.5)
plt.show()
# Out:
# C:\Users\RaviKiran\anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\RaviKiran\anaconda3\lib\site-packages\seaborn\categorical.py:3710: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\RaviKiran\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.factorplot("Qual_miles",data=data,kind='count',size=5,aspect=.5)
plt.show()
# Out:
# C:\Users\RaviKiran\anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\RaviKiran\anaconda3\lib\site-packages\seaborn\categorical.py:3710: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\RaviKiran\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.factorplot("Bonus_trans",data=data,kind='count',size=5,aspect=.5)
plt.show()
# Out:
# C:\Users\RaviKiran\anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\RaviKiran\anaconda3\lib\site-packages\seaborn\categorical.py:3710: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\RaviKiran\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.factorplot("Flight_trans_12",data=data,kind='count',size=5,aspect=.5)
plt.show()
# Out:
# C:\Users\RaviKiran\anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\RaviKiran\anaconda3\lib\site-packages\seaborn\categorical.py:3710: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\RaviKiran\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.factorplot("cc1_miles",data=data,kind='count',size=5,aspect=.5)
plt.show()
# Out:
# C:\Users\RaviKiran\anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\RaviKiran\anaconda3\lib\site-packages\seaborn\categorical.py:3710: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\RaviKiran\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.factorplot("cc2_miles",data=data,kind='count',size=5,aspect=.5)
plt.show()
# Out:
# C:\Users\RaviKiran\anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\RaviKiran\anaconda3\lib\site-packages\seaborn\categorical.py:3710: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\RaviKiran\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.factorplot("cc3_miles",data=data,kind='count',size=5,aspect=.5)
plt.show()
# Out:
# C:\Users\RaviKiran\anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\RaviKiran\anaconda3\lib\site-packages\seaborn\categorical.py:3710: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\RaviKiran\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.factorplot("Flight_miles_12mo",data=data,kind='count',size=5,aspect=.5)
plt.show()
# Out:
# C:\Users\RaviKiran\anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\RaviKiran\anaconda3\lib\site-packages\seaborn\categorical.py:3710: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\RaviKiran\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.factorplot("Flight_trans_12",data=data,kind='count',size=5,aspect=.5)
plt.show()
# Out:
# C:\Users\RaviKiran\anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\RaviKiran\anaconda3\lib\site-packages\seaborn\categorical.py:3710: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\RaviKiran\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.factorplot("Days_since_enroll",data=data,kind='count',size=5,aspect=.5)
plt.show()
# Out:
# C:\Users\RaviKiran\anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\RaviKiran\anaconda3\lib\site-packages\seaborn\categorical.py:3710: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\RaviKiran\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(data=data)
# Out:
# <AxesSubplot:>

# %% [markdown]
# When We are Dealing With the distances we Need to Normalize or Standardise the data in between 0 and 1

# %%
data
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 0               1                  0                0               7000
# 1               2                  0                0               6968
# 2               4                  0                0               7034
# 3               1                  0                0               6952
# 4              26               2077                4               6935
# ...           ...                ...              ...                ...
# 3994            4                200                1               1403
# 3995            5                  0                0               1395
# 3996            8                  0                0               1402
# 3997            1                500                1               1401
# 3998            0                  0                0               1398
#
#       Award?
# 0          0
# 1          0
# 2          0
# 3          0
# 4          1
# ...      ...
# 3994       1
# 3995       1
# 3996       1
# 3997       0
# 3998       0
#
# [3999 rows x 12 columns]

# %% [markdown]
# #Normalization and Standardization

# %%
def nrml_data(i):
    x=(i-i.min())/(i.max()-i.min())
    return x

# %%
normal_data = nrml_data(data)

# %%
normal_data
# Out:
#            ID#   Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# 0     0.000000  0.016508         0.0       0.00        0.0        0.0
# 1     0.000249  0.011288         0.0       0.00        0.0        0.0
# 2     0.000498  0.024257         0.0       0.00        0.0        0.0
# 3     0.000746  0.008667         0.0       0.00        0.0        0.0
# 4     0.000995  0.057338         0.0       0.75        0.0        0.0
# ...        ...       ...         ...        ...        ...        ...
# 3994  0.999005  0.010837         0.0       0.00        0.0        0.0
# 3995  0.999254  0.037766         0.0       0.00        0.0        0.0
# 3996  0.999502  0.043169         0.0       0.50        0.0        0.0
# 3997  0.999751  0.032202         0.0       0.00        0.0        0.0
# 3998  1.000000  0.001769         0.0       0.00        0.0        0.0
#
#       Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# 0        0.000660     0.011628           0.000000         0.000000
# 1        0.000815     0.023256           0.000000         0.000000
# 2        0.015636     0.046512           0.000000         0.000000
# 3        0.001896     0.011628           0.000000         0.000000
# 4        0.164211     0.302326           0.067398         0.075472
# ...           ...          ...                ...              ...
# 3994     0.032330     0.046512           0.006490         0.018868
# 3995     0.003720     0.058140           0.000000         0.000000
# 3996     0.096505     0.093023           0.000000         0.000000
# 3997     0.001896     0.011628           0.016225         0.018868
# 3998     0.000000     0.000000           0.000000         0.000000
#
#       Days_since_enroll  Award?
# 0              0.843742     0.0
# 1              0.839884     0.0
# 2              0.847842     0.0
# 3              0.837955     0.0
# 4              0.835905     1.0
# ...                 ...     ...
# 3994           0.168917     1.0
# 3995           0.167953     1.0
# 3996           0.168797     1.0
# 3997           0.168676     0.0
# 3998           0.168314     0.0
#
# [3999 rows x 12 columns]

# %%
import scipy.cluster.hierarchy as sch
from scipy.cluster.hierarchy import linkage
from sklearn.cluster import AgglomerativeClustering

# %%
rk=linkage(normal_data,method='complete',metric='euclidean')
plt.figure(figsize=(15,15))
plt.title("Dendrogram of East West Airlines by Complete Method")
plt.xlabel('Index')
plt.ylabel('Distance')
sch.dendrogram(rk,)
plt.show()

# %%
rk=linkage(normal_data,method="single",metric="euclidean")
plt.figure(figsize=(15,15))
plt.title("Dendrogram of East West Airlines by Complete Method")
plt.xlabel('Index')
plt.ylabel('Distance')
sch.dendrogram(rk)
plt.show()

# %%
rk=linkage(normal_data,method='average',metric='euclidean')
plt.figure(figsize=(15,15))
plt.title("Dendrogram of East West Airlines by Complete Method")
plt.xlabel('Index')
plt.ylabel('Distance')
sch.dendrogram(rk)
plt.show()

# %%
rk=linkage(normal_data,method='centroid',metric='euclidean')
plt.figure(figsize=(15,15))
plt.title("Dendrogram of East West Airlines by Complete Method")
plt.xlabel('Index')
plt.ylabel('Distance')
sch.dendrogram(rk)
plt.show()

# %% [markdown]
# From the above  all the Dendrogram we can clearly and easily understand the Complete Linkage Dendrogram without any complexity

# %% [markdown]
# Now We Form Clusters based on Dendrogram

# %%
from sklearn.cluster import AgglomerativeClustering
hc_clusters=AgglomerativeClustering(n_clusters=7 ,linkage='complete',affinity='euclidean' ,).fit(normal_data)
clusters=pd.Series(hc_clusters.labels_)
clusters
# Out:
# 0       6
# 1       6
# 2       6
# 3       6
# 4       0
#        ..
# 3994    2
# 3995    2
# 3996    2
# 3997    3
# 3998    3
# Length: 3999, dtype: int64

# %%
data['Clusters']=clusters

# %%
data
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 0               1                  0                0               7000
# 1               2                  0                0               6968
# 2               4                  0                0               7034
# 3               1                  0                0               6952
# 4              26               2077                4               6935
# ...           ...                ...              ...                ...
# 3994            4                200                1               1403
# 3995            5                  0                0               1395
# 3996            8                  0                0               1402
# 3997            1                500                1               1401
# 3998            0                  0                0               1398
#
#       Award?  Clusters
# 0          0         6
# 1          0         6
# 2          0         6
# 3          0         6
# 4          1         0
# ...      ...       ...
# 3994       1         2
# 3995       1         2
# 3996       1         2
# 3997       0         3
# 3998       0         3
#
# [3999 rows x 13 columns]

# %%
data.iloc[:,0:].groupby(data['Clusters']).mean()
# Out:
#                   ID#        Balance  Qual_miles  cc1_miles  cc2_miles  \
# Clusters
# 0         1201.632841  120206.490775  154.529520   4.121771   1.001845
# 1         2113.857143   55387.685714   28.571429   1.028571   2.428571
# 2         2716.744817   65604.537480  196.371611   2.020734   1.009569
# 3         2902.386220   46942.534766  102.988622   1.510114   1.000632
# 4          684.607383  121041.607383  491.486577   1.409396   1.000000
# 5         3128.000000  131999.500000  347.000000   2.500000   1.000000
# 6          900.652031   82596.805708   63.287596   2.063666   1.000000
#
#           cc3_miles   Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# Clusters
# 0          1.044280  51732.154982    20.808118         762.031365
# 1          1.000000  14254.571429    16.342857         398.657143
# 2          1.001595  17800.588517    13.043062         781.886762
# 3          1.005057   7686.658028     8.541087         233.170670
# 4          1.006711  10519.322148    11.456376         928.362416
# 5          1.000000  65634.250000    69.250000       19960.000000
# 6          1.015368  14605.867179    10.060373         216.441273
#
#           Flight_trans_12  Days_since_enroll    Award?  Clusters
# Clusters
# 0                2.302583        5548.643911  1.000000       0.0
# 1                1.771429        4139.228571  0.285714       1.0
# 2                2.358852        2943.051037  1.000000       2.0
# 3                0.650442        2528.217446  0.000000       3.0
# 4                2.949664        6483.204698  1.000000       4.0
# 5               49.250000        2200.250000  1.000000       5.0
# 6                0.657519        6072.614709  0.000000       6.0

# %%
data['Clusters'].value_counts()
# Out:
# 3    1582
# 6     911
# 2     627
# 0     542
# 4     298
# 1      35
# 5       4
# Name: Clusters, dtype: int64

# %%
data1=data[(data.Clusters == 0)]
data1
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 4        5    97752           0          4          1          1        43300
# 8        9   443003           0          3          2          1         1753
# 11      12    96522           0          5          1          1        61105
# 15      16    28495           0          4          1          1        49442
# 16      17    51890           0          4          1          1        48963
# ...    ...      ...         ...        ...        ...        ...          ...
# 2549  2568   140398           0          5          1          1       118013
# 2553  2572    34781           0          3          1          1        11270
# 2554  2573    22457           0          3          1          1        17579
# 2561  2580    40702           0          4          1          1        39897
# 2583  2602    11529           0          3          1          1        15738
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 4              26               2077                4               6935
# 8              43               3850               12               6948
# 11             19                  0                0               6924
# 15             15                  0                0               6912
# 16             16                  0                0               6910
# ...           ...                ...              ...                ...
# 2549           26               1100                4               2972
# 2553           12                  0                0               2859
# 2554           15                  0                0               2858
# 2561           14                  0                0               2826
# 2583           15                  0                0               2768
#
#       Award?  Clusters
# 4          1         0
# 8          1         0
# 11         1         0
# 15         1         0
# 16         1         0
# ...      ...       ...
# 2549       1         0
# 2553       1         0
# 2554       1         0
# 2561       1         0
# 2583       1         0
#
# [542 rows x 13 columns]

# %%
data1=data[(data.Clusters == 1)]
data1
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 198    202     8669           0          1          3          1        11397
# 226    230   117329           0          1          2          1         6448
# 381    386   167670           0          1          3          1        15907
# 392    398    11189           0          1          2          1         9044
# 561    568   380930           0          2          2          1        22485
# 794    804    55610           0          1          2          1         5095
# 940    951    44824           0          1          3          1        21107
# 1149  1161    84856           0          1          2          1         6894
# 1270  1283    16103           0          1          3          1        10819
# 1383  1397    18154           0          1          2          1         7748
# 1389  1403    49145           0          1          2          1        12755
# 1527  1542    23965           0          1          2          1         7308
# 1541  1556    36887           0          1          2          1         9048
# 1791  1808    32510           0          1          3          1        14568
# 1918  1935    52139           0          1          3          1        16314
# 1976  1993    11961           0          1          2          1        11961
# 2006  2023   101901           0          1          2          1        17898
# 2047  2064     4148           0          1          3          1        13504
# 2166  2183   100634           0          1          3          1        69669
# 2278  2296    30171           0          1          3          1        15370
# 2317  2335    10458           0          1          2          1        10458
# 2421  2440    41062           0          1          2          1         8275
# 2741  2763    42970           0          1          2          1         7889
# 2906  2928    17769           0          1          2          1         5165
# 2978  3000    22805           0          1          3          1        26334
# 2999  3021   142527        1000          1          3          1        24091
# 3155  3177    21736           0          1          2          1         6672
# 3191  3213    56624           0          1          2          1        12311
# 3203  3225    64924           0          1          3          1        14971
# 3359  3382    20318           0          1          2          1         6990
# 3367  3390    23197           0          1          3          1        10587
# 3487  3510    38292           0          1          2          1        12487
# 3611  3634    37300           0          1          3          1        23760
# 3779  3802    35850           0          1          3          1        17759
# 3959  3982    13942           0          1          2          1         5822
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 198            16                  0                0               7486
# 226            11                  0                0               7416
# 381            13                  0                0               6994
# 392            20                  0                0               8296
# 561            25                213                1               6539
# 794            13                  0                0               6151
# 940            19               2000                4               5916
# 1149           13                  0                0               5547
# 1270           13                  0                0               5427
# 1383           16                  0                0               5310
# 1389           22               2450                7               5323
# 1527           16                550                3               5003
# 1541           11                  0                0               4951
# 1791           13                  0                0               4341
# 1918           14                250                1               3965
# 1976           10                  0                0               4646
# 2006           22                100                1               4433
# 2047           18                  0                0               4607
# 2166           28               1540               12               4193
# 2278           13                  0                0               3853
# 2317           12                  0                0               3726
# 2421           11                  0                0               3356
# 2741           14                  0                0               2256
# 2906           10                  0                0               1807
# 2978           27               1800                6               3294
# 2999           47               4650               24               3206
# 3155           10                  0                0               2544
# 3191           14                  0                0               2491
# 3203           13                  0                0               1989
# 3359           13                  0                0               1956
# 3367           13                150                1               1747
# 3487           13                250                2                531
# 3611           19                  0                0                676
# 3779           18                  0                0               3439
# 3959           12                  0                0               1458
#
#       Award?  Clusters
# 198        1         1
# 226        1         1
# 381        0         1
# 392        1         1
# 561        1         1
# 794        0         1
# 940        1         1
# 1149       0         1
# 1270       0         1
# 1383       1         1
# 1389       0         1
# 1527       0         1
# 1541       0         1
# 1791       0         1
# 1918       0         1
# 1976       0         1
# 2006       0         1
# 2047       1         1
# 2166       1         1
# 2278       0         1
# 2317       0         1
# 2421       0         1
# 2741       0         1
# 2906       0         1
# 2978       1         1
# 2999       1         1
# 3155       0         1
# 3191       0         1
# 3203       0         1
# 3359       0         1
# 3367       0         1
# 3487       0         1
# 3611       0         1
# 3779       0         1
# 3959       0         1

# %%
data1=data[(data.Clusters == 2)]
data1
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 1039  1050    57434           0          2          1          1        11140
# 1096  1108    68610           0          2          1          1         6115
# 1136  1148    24418           0          2          1          1        12533
# 1164  1176    23379           0          2          1          1        11712
# 1170  1182    56451           0          2          1          1         9302
# ...    ...      ...         ...        ...        ...        ...          ...
# 3987  4010    11933           0          1          1          1          249
# 3989  4012     2622           0          1          1          1         1625
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 1039           16                  0                0               5770
# 1096           12                  0                0               5349
# 1136           13                  0                0               5626
# 1164           25                  0                0               5499
# 1170           11                  0                0               5597
# ...           ...                ...              ...                ...
# 3987            3                 79                1               1412
# 3989            6                  0                0               1404
# 3994            4                200                1               1403
# 3995            5                  0                0               1395
# 3996            8                  0                0               1402
#
#       Award?  Clusters
# 1039       1         2
# 1096       1         2
# 1136       1         2
# 1164       1         2
# 1170       1         2
# ...      ...       ...
# 3987       1         2
# 3989       1         2
# 3994       1         2
# 3995       1         2
# 3996       1         2
#
# [627 rows x 13 columns]

# %%
data1=data[(data.Clusters == 3)]
data1
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 1109  1121    73640           0          2          1          1        10192
# 1129  1141     1625           0          1          1          1         1375
# 1234  1247    33020           0          1          1          1         6155
# 1248  1261    81291           0          2          1          1        10522
# 1287  1300    21599           0          2          1          1         5561
# ...    ...      ...         ...        ...        ...        ...          ...
# 3991  4014    39142           0          3          1          1        14981
# 3992  4015    11181           0          1          1          1          929
# 3993  4016     3974           0          1          1          1          365
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 1109           14                  0                0               5156
# 1129            4                  0                0               1547
# 1234           25               1500                3               5322
# 1248           14               1430                1               5154
# 1287           13                  0                0               5302
# ...           ...                ...              ...                ...
# 3991           28                  0                0               1408
# 3992           12                  0                0               1407
# 3993            3                  0                0               1397
# 3997            1                500                1               1401
# 3998            0                  0                0               1398
#
#       Award?  Clusters
# 1109       0         3
# 1129       0         3
# 1234       0         3
# 1248       0         3
# 1287       0         3
# ...      ...       ...
# 3991       0         3
# 3992       0         3
# 3993       0         3
# 3997       0         3
# 3998       0         3
#
# [1582 rows x 13 columns]

# %%
data1=data[(data.Clusters == 4)]
data1
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 7        8    20856           0          1          1          1         5250
# 9       10   104860           0          3          1          1        28426
# 17      18    13958           0          1          1          1         4291
# 18      19    91473           0          3          1          1        27408
# 19      20    23354           0          3          1          1        10447
# ...    ...      ...         ...        ...        ...        ...          ...
# 1623  1638   194949           0          1          1          1        10121
# 1667  1683    25688        2396          1          1          1         3103
# 1669  1685   288379           0          1          1          1        15942
# 1698  1714   192108        1000          1          1          1        10200
# 2004  2021   354807           0          1          1          1         6000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 7               4                250                1               6938
# 9              28               1150                3               6931
# 17              5                  0                0               6905
# 18             17                  0                0               6903
# 19              5                  0                0               6896
# ...           ...                ...              ...                ...
# 1623           13               4621               10               4930
# 1667           10                  0                0               4754
# 1669            8               1442                5               4741
# 1698            3                200                2               4656
# 2004           12               3500               11               4597
#
#       Award?  Clusters
# 7          1         4
# 9          1         4
# 17         1         4
# 18         1         4
# 19         1         4
# ...      ...       ...
# 1623       1         4
# 1667       1         4
# 1669       1         4
# 1698       1         4
# 2004       1         4
#
# [298 rows x 13 columns]

# %%
data1=data[(data.Clusters == 5)]
data1
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 2015  2032    53232         888          4          1          1        80696
# 3235  3257   287033           0          1          1          1        26161
# 3583  3606   160114         500          1          1          1        71954
# 3594  3617    27619           0          4          1          1        83726
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 2015           65              22100               45               3831
# 3235           58              12873               53               2272
# 3583           86              30817               53               1373
# 3594           68              14050               46               1325
#
#       Award?  Clusters
# 2015       1         5
# 3235       1         5
# 3583       1         5
# 3594       1         5
